# %%
# !pip install langchain chromadb openai tiktoken pypdf langchain_openai langchain-community
# Out:
# Requirement already satisfied: langchain in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (1.2.12)
# Collecting chromadb
#   Downloading chromadb-1.5.5-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.2 kB)
# Requirement already satisfied: openai in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (2.28.0)
# Requirement already satisfied: tiktoken in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (0.12.0)
# Requirement already satisfied: pypdf in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (6.9.0)
# Requirement already satisfied: langchain_openai in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (1.1.11)
# Requirement already satisfied: langchain-community in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain) (1.2.19)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.12.1)
# Requirement already satisfied: certifi in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.4.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic-settings>=2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb) (2.13.1)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.41.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: numpy>=1.22.5 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb) (2.4.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.24.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (5.1 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.40.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.40.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.40.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb) (4.67.3)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb) (1.78.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting rich>=10.11.0 (from chromadb)
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from openai) (0.13.0)
# Requirement already satisfied: sniffio in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from tiktoken) (2026.2.19)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Using cached websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: protobuf in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: sympy in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.40.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.40.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.40.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.40.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-semantic-conventions==0.61b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb) (0.36.2)
# Requirement already satisfied: filelock in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.3.1)
# Requirement already satisfied: click>=8.2.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.9.0->chromadb)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.7.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvloop-0.22.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-1.1.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.5.5-cp39-abi3-macosx_11_0_arm64.whl (20.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 30.4 MB/s  0:00:00 eta 0:00:01
# Downloading bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl (495 kB)
# Downloading build-1.4.0-py3-none-any.whl (24 kB)
# Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 38.7 MB/s  0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.1-cp313-cp313-macosx_11_0_arm64.whl (40 kB)
# Downloading onnxruntime-1.24.3-cp313-cp313-macosx_14_0_arm64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 49.6 MB/s  0:00:00 eta 0:00:01
# Using cached opentelemetry_api-1.40.0-py3-none-any.whl (68 kB)
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.40.0-py3-none-any.whl (20 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.40.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.40.0-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.40.0-py3-none-any.whl (141 kB)
# Using cached opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl (231 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.4.3-cp313-cp313-macosx_11_0_arm64.whl (31 kB)
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached uvicorn-0.41.0-py3-none-any.whl (68 kB)
# Using cached httptools-0.7.1-cp313-cp313-macosx_11_0_arm64.whl (108 kB)
# Using cached uvloop-0.22.1-cp313-cp313-macosx_10_13_universal2.whl (1.4 MB)
# Using cached watchfiles-1.1.1-cp313-cp313-macosx_11_0_arm64.whl (391 kB)
# Using cached websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pypika, flatbuffers, durationpy, zipp, websocket-client, uvloop, uvicorn, shellingham, pyproject_hooks, pybase64, overrides, opentelemetry-proto, oauthlib, mmh3, mdurl, importlib-resources, httptools, bcrypt, annotated-doc, watchfiles, requests-oauthlib, opentelemetry-exporter-otlp-proto-common, onnxruntime, markdown-it-py, importlib-metadata, build, rich, opentelemetry-api, kubernetes, typer, opentelemetry-semantic-conventions, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34/34 [chromadb]/34 [chromadb]s]]y-proto]
# Successfully installed annotated-doc-0.0.4 bcrypt-5.0.0 build-1.4.0 chromadb-1.5.5 durationpy-0.10 flatbuffers-25.12.19 httptools-0.7.1 importlib-metadata-8.7.1 importlib-resources-6.5.2 kubernetes-35.0.0 markdown-it-py-4.0.0 mdurl-0.1.2 mmh3-5.2.1 oauthlib-3.3.1 onnxruntime-1.24.3 opentelemetry-api-1.40.0 opentelemetry-exporter-otlp-proto-common-1.40.0 opentelemetry-exporter-otlp-proto-grpc-1.40.0 opentelemetry-proto-1.40.0 opentelemetry-sdk-1.40.0 opentelemetry-semantic-conventions-0.61b0 overrides-7.7.0 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 rich-14.3.3 shellingham-1.5.4 typer-0.24.1 uvicorn-0.41.0 uvloop-0.22.1 watchfiles-1.1.1 websocket-client-1.9.0 zipp-3.23.0

# %%
pip install -U langchain-chroma
# Out:
# Collecting langchain-chroma
#   Downloading langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-chroma) (1.5.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-chroma) (1.2.19)
# Requirement already satisfied: numpy>=2.1.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-chroma) (2.4.2)
# Requirement already satisfied: build>=1.0.3 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.0)
# Requirement already satisfied: pydantic>=2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.12.5)
# Requirement already satisfied: pydantic-settings>=2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.41.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.24.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.78.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Requirement already satisfied: anyio in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.12.1)
# Requirement already satisfied: certifi in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Requirement already satisfied: pyproject_hooks in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: flatbuffers in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: protobuf in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.29.6)
# Requirement already satisfied: sympy in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.61b0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic-settings>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.36.2)
# Requirement already satisfied: filelock in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.1)
# Requirement already satisfied: click>=8.2.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)
# Downloading langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Installing collected packages: langchain-chroma
# Successfully installed langchain-chroma-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# %%
from langchain_core.documents import Document

doc1 = Document(
    page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
    metadata={"team": "Royal Challengers Bangalore"}
)

doc2 = Document(
    page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
    metadata={"team": "Mumbai Indians"}
)

doc3 = Document(
    page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
    metadata={"team": "Chennai Super Kings"}
)

doc4 = Document(
    page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
    metadata={"team": "Mumbai Indians"}
)

doc5 = Document(
    page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
    metadata={"team": "Chennai Super Kings"}
)

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function=OpenAIEmbeddings(),
    persist_directory='my_chroma_db',
    collection_name='sample'
)

# %%
# add documents
vector_store.add_documents(docs)
# Out:
# ['1922ebdb-856a-4720-83ac-7c2572f18659',
#  '84d09c52-9a3a-4382-a541-80c1f1bab5a9',
#  '30c4919d-c56e-4bbc-9655-963a91395e86',
#  'c301c3be-ebd3-48c2-8bc8-c95d1c26b51d',
#  'f4794948-f739-4ac6-ae08-838f26087fac']

# %%
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['1922ebdb-856a-4720-83ac-7c2572f18659',
#   '84d09c52-9a3a-4382-a541-80c1f1bab5a9',
#   '30c4919d-c56e-4bbc-9655-963a91395e86',
#   'c301c3be-ebd3-48c2-8bc8-c95d1c26b51d',
#   'f4794948-f739-4ac6-ae08-838f26087fac'],
#  'embeddings': array([[-0.00210453, -0.00214285,  0.0268    , ..., -0.01707893,
#          -0.00366616,  0.01357884],
#         [-0.00268021, -0.00010323,  0.02815653, ..., -0.01501936,
#           0.00590092, -0.01164922],
#         [ 0.00092799, -0.00476   ,  0.0124662 , ..., -0.01731381,
#           0.00075886,  0.00296567],
#         [-0.02714536,  0.00885395,  0.02699314, ..., -0.02592762,
#           0.00900617, -0.01999116],
#         [-0.01810451,  0.01281202,  0.0347942 , ..., -0.03034012,
#          -0.00595078,  0.00521716]], shape=(5, 1536)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
vector_store.similarity_search(query='who is the bowler',
                               k=2)
# Out:
# [Document(id='c301c3be-ebd3-48c2-8bc8-c95d1c26b51d', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='f4794948-f739-4ac6-ae08-838f26087fac', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.')]

# %%
vector_store.similarity_search_with_score(query='who is the bowler',
                               k=2)
# Out:
# [(Document(id='c301c3be-ebd3-48c2-8bc8-c95d1c26b51d', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.42470571398735046),
#  (Document(id='f4794948-f739-4ac6-ae08-838f26087fac', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.5218799114227295)]

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(id='30c4919d-c56e-4bbc-9655-963a91395e86', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   0.648826003074646),
#  (Document(id='f4794948-f739-4ac6-ae08-838f26087fac', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.6566494703292847)]

# %%
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='09a39dc6-3ba6-4ea7-927e-fdda591da5e4', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['1922ebdb-856a-4720-83ac-7c2572f18659',
#   '84d09c52-9a3a-4382-a541-80c1f1bab5a9',
#   '30c4919d-c56e-4bbc-9655-963a91395e86',
#   'c301c3be-ebd3-48c2-8bc8-c95d1c26b51d',
#   'f4794948-f739-4ac6-ae08-838f26087fac'],
#  'embeddings': array([[-0.00210453, -0.00214285,  0.0268    , ..., -0.01707893,
#          -0.00366616,  0.01357884],
#         [-0.00268021, -0.00010323,  0.02815653, ..., -0.01501936,
#           0.00590092, -0.01164922],
#         [ 0.00092799, -0.00476   ,  0.0124662 , ..., -0.01731381,
#           0.00075886,  0.00296567],
#         [-0.02714536,  0.00885395,  0.02699314, ..., -0.02592762,
#           0.00900617, -0.01999116],
#         [-0.01810451,  0.01281202,  0.0347942 , ..., -0.03034012,
#          -0.00595078,  0.00521716]], shape=(5, 1536)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
vector_store.delete(ids=['09a39dc6-3ba6-4ea7-927e-fdda591da5e4'])

# %%
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['1922ebdb-856a-4720-83ac-7c2572f18659',
#   '84d09c52-9a3a-4382-a541-80c1f1bab5a9',
#   '30c4919d-c56e-4bbc-9655-963a91395e86',
#   'c301c3be-ebd3-48c2-8bc8-c95d1c26b51d',
#   'f4794948-f739-4ac6-ae08-838f26087fac'],
#  'embeddings': array([[-0.00210453, -0.00214285,  0.0268    , ..., -0.01707893,
#          -0.00366616,  0.01357884],
#         [-0.00268021, -0.00010323,  0.02815653, ..., -0.01501936,
#           0.00590092, -0.01164922],
#         [ 0.00092799, -0.00476   ,  0.0124662 , ..., -0.01731381,
#           0.00075886,  0.00296567],
#         [-0.02714536,  0.00885395,  0.02699314, ..., -0.02592762,
#           0.00900617, -0.01999116],
#         [-0.01810451,  0.01281202,  0.0347942 , ..., -0.03034012,
#          -0.00595078,  0.00521716]], shape=(5, 1536)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}
