# %%
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
from langchain_community.vectorstores import FAISS
from langchain_openai import ChatOpenAI
from langchain_classic.retrievers import MultiQueryRetriever

# %%
 pip install -U langchain-classic
# Out:
# Requirement already satisfied: langchain-classic in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (1.0.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.19 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-classic) (1.2.19)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-classic) (1.1.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-classic) (0.7.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-classic) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-classic) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-classic) (2.0.48)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (26.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.19->langchain-classic) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.25.0)
# Requirement already satisfied: anyio in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (4.12.1)
# Requirement already satisfied: certifi in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.9)
# Requirement already satisfied: idna in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/avdhipagaria/Desktop/LANGCHAIN_MODELS/venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Relevant health & wellness documents
all_docs = [
    Document(page_content="Regular walking boosts heart health and can reduce symptoms of depression.", metadata={"source": "H1"}),
    Document(page_content="Consuming leafy greens and fruits helps detox the body and improve longevity.", metadata={"source": "H2"}),
    Document(page_content="Deep sleep is crucial for cellular repair and emotional regulation.", metadata={"source": "H3"}),
    Document(page_content="Mindfulness and controlled breathing lower cortisol and improve mental clarity.", metadata={"source": "H4"}),
    Document(page_content="Drinking sufficient water throughout the day helps maintain metabolism and energy.", metadata={"source": "H5"}),
    Document(page_content="The solar energy system in modern homes helps balance electricity demand.", metadata={"source": "I1"}),
    Document(page_content="Python balances readability with power, making it a popular system design language.", metadata={"source": "I2"}),
    Document(page_content="Photosynthesis enables plants to produce energy by converting sunlight.", metadata={"source": "I3"}),
    Document(page_content="The 2022 FIFA World Cup was held in Qatar and drew global energy and excitement.", metadata={"source": "I4"}),
    Document(page_content="Black holes bend spacetime and store immense gravitational energy.", metadata={"source": "I5"}),
]

# %%
embedding_model=OpenAIEmbeddings()

vectorstore=FAISS.from_documents(documents=all_docs,embedding=embedding_model)

# %%
similarity_retriever=vectorstore.as_retriever(search_type="similarity",search_kwargs={"k": 5})

# %%
multiquery_retriever=MultiQueryRetriever.from_llm(
    llm=ChatOpenAI(),
    retriever=vectorstore.as_retriever(search_kwargs={"k": 5})
)

# %%
# Query
query = "How to improve energy levels and maintain balance?"

# %%
similarity_results = similarity_retriever.invoke(query)
multiquery_results= multiquery_retriever.invoke(query)

# %%
for i, doc in enumerate(similarity_results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)

print("*"*150)

for i, doc in enumerate(multiquery_results):
    print(f"\n--- Result {i+1} ---")
    print(doc.page_content)
# Out:
# --- Result 1 ---
# Drinking sufficient water throughout the day helps maintain metabolism and energy.
#
# --- Result 2 ---
# Mindfulness and controlled breathing lower cortisol and improve mental clarity.
#
# --- Result 3 ---
# Regular walking boosts heart health and can reduce symptoms of depression.
#
# --- Result 4 ---
# Deep sleep is crucial for cellular repair and emotional regulation.
#
# --- Result 5 ---
# The solar energy system in modern homes helps balance electricity demand.
# ******************************************************************************************************************************************************
#
# --- Result 1 ---
# Drinking sufficient water throughout the day helps maintain metabolism and energy.
#
# --- Result 2 ---
# Mindfulness and controlled breathing lower cortisol and improve mental clarity.
#
# --- Result 3 ---
# Regular walking boosts heart health and can reduce symptoms of depression.
#
# --- Result 4 ---
# Deep sleep is crucial for cellular repair and emotional regulation.
#
# --- Result 5 ---
# Consuming leafy greens and fruits helps detox the body and improve longevity.
#
# --- Result 6 ---
# The solar energy system in modern homes helps balance electricity demand.
#
# --- Result 7 ---
# Black holes bend spacetime and store immense gravitational energy.
